# %%
from DataStructures.NeuralNetworks import RBF

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-1, 1, 50)
Y = np.sin((X + 0.5)**3)
Y_noised = np.sin((X + 0.5)**3) + np.random.randn(50) / 10

# %% [markdown]
# ## Plot function

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot()
ax.plot(X, Y)
ax.plot(X, Y_noised)
ax.title.set_text("y = sin(x+0.5)**3")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## RBF Network

# %%
rbf = RBF(K=20)
rbf.fit(X, Y_noised)

# %%
rbf.weights
# Out:
# array([ 3.34421433e+10,  6.04044145e+10,  5.71561384e+10,  8.12306079e+10,
#        -1.30238606e+11,  9.86629474e+10, -6.35098474e+10,  6.31589479e+10,
#        -8.45446409e+10, -5.73406537e+06,  2.61605777e+10, -8.10389177e+10,
#        -5.71469576e+09, -4.07122298e+09, -1.00973834e+10,  9.81176143e+09,
#        -7.07742939e+10, -8.70435588e+10, -3.18090083e+09,  1.10192249e+11])

# %%
rbf_predict = rbf.predict(X)

# %%
def plot_result(X, Y, Y_noised, rbf_predict, title="f(x) = sin((x+0.5)**3)"):
    fig = plt.figure(figsize=(10,7))
    ax = fig.add_subplot()
    ax.plot(X, Y, color="blue", linewidth=3)
    ax.plot(X, Y_noised, color="red", linewidth=3, linestyle='dotted')
    ax.plot(X, rbf_predict, color="black", linewidth=3, linestyle='dashed')
    ax.legend(["f(x)", "f(x) with noise", "RBF for f(x)"])
    ax.title.set_text(title)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    plt.show()
plot_result(X, Y, Y_noised, rbf_predict)

# %% [markdown]
# ## Check RBF results for different number of joints

# %%
def test_rbf(k=1):
    rbf2 = RBF(K=k)
    rbf2.fit(X, Y_noised)
    rbf2_predict = rbf2.predict(X)
    plot_result(X, Y, Y_noised, rbf2_predict, title=f"RBF for {k} joint(s)")

# %%
for i in range(1, 41, 2):
    test_rbf(k=i)
